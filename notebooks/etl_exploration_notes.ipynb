# %% [markdown]
# # ETL Exploration Notes
#
# This notebook is a placeholder for manual exploration, assumptions, and future experiments. The production pipeline lives in `scripts/run_pipeline.py` and `src/`.
